# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740/blob/main/A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_stata('https://raw.githubusercontent.com/havaledar/ECON3740/main/LFS-71M0001-E-2023-August_F1.dta')
df

# %%
# Convert 'SEX' column to categorical and get dummies
sex_dummies = pd.get_dummies(df['SEX'], prefix='gender')
sex_dummies
# Out:
#         gender_Male  gender_Female
# 0                 0              1
# 1                 1              0
# 2                 1              0
# 3                 1              0
# 4                 1              0
# ...             ...            ...
# 103398            0              1
# 103399            1              0
# 103400            0              1
# 103401            0              1
# 103402            0              1
#
# [103403 rows x 2 columns]

# %%
# Take only one column as 0 and 1 are inversely related
df['gender'] = sex_dummies["gender_Female"]

# %%
# Display the first few rows of the DataFrame with the new 'gender' column
print(df[['SEX', 'gender']].head())
# Out:
#       SEX  gender
# 0  Female       1
# 1    Male       0
# 2    Male       0
# 3    Male       0
# 4    Male       0

# %%
df['lwage'] = np.log(df['HRLYEARN'])

# %%
df_notna = df.dropna(subset=['lwage'])

# %%
# If we import the values we can use
# df_notna['sex'] = df_notna['SEX'] - 1

# %%
df_notna['HRLYEARN'].isna().sum()
# Out:
# 0

# %%
# Group by 'sex' and calculate the average of 'HRLYEARN'
data_averages = df_notna.groupby('SEX')['HRLYEARN'].mean().reset_index(name='wage')
data_averages
# Out:
#       SEX       wage
# 0    Male  34.937034
# 1  Female  30.918263

# %%
import statsmodels.formula.api as smf

# Create a simple linear regression model
model = smf.ols('HRLYEARN ~ C(gender)', data = df_notna)
results = model.fit()

# Display the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               HRLYEARN   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     692.6
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):          1.15e-151
# Time:                        04:24:24   Log-Likelihood:            -2.2925e+05
# No. Observations:               53443   AIC:                         4.585e+05
# Df Residuals:                   53441   BIC:                         4.585e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         34.9370      0.107    326.087      0.000      34.727      35.147
# C(gender)[T.1]    -4.0188      0.153    -26.317      0.000      -4.318      -3.719
# ==============================================================================
# Omnibus:                    24300.546   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           171509.035
# Skew:                           2.066   Prob(JB):                         0.00
# Kurtosis:                      10.742   Cond. No.                         2.60
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Create the log wage regression model with categorical variables using formula notation
model = smf.ols(formula="lwage ~ C(EDUC) + C(AGE_12) + C(SEX) + C(MARSTAT) + C(PROV)", data=df_notna)
results = model.fit()

# Display the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  lwage   R-squared:                       0.339
# Model:                            OLS   Adj. R-squared:                  0.339
# Method:                 Least Squares   F-statistic:                     855.8
# Date:                Thu, 09 Nov 2023   Prob (F-statistic):               0.00
# Time:                        04:29:02   Log-Likelihood:                -24221.
# No. Observations:               53443   AIC:                         4.851e+04
# Df Residuals:                   53410   BIC:                         4.880e+04
# Df Model:                          32
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           2.8379      0.019    152.564      0.000       2.801       2.874
# C(EDUC)[T.Some high school]                         0.0476      0.016      2.919      0.004       0.016       0.079
# C(EDUC)[T.High school graduate]                     0.1155      0.015      7.457      0.000       0.085       0.146
# C(EDUC)[T.Some postsecondary]                       0.1793      0.017     10.751      0.000       0.147       0.212
# C(EDUC)[T.Postsecondary certificate or diploma]     0.2707      0.015     17.701      0.000       0.241       0.301
# C(EDUC)[T.Bachelor's degree]                        0.4596      0.016     29.595      0.000       0.429       0.490
# C(EDUC)[T.Above bachelor's degree]                  0.5820      0.016     36.377      0.000       0.551       0.613
# C(AGE_12)[T.20 to 24 years]                         0.0680      0.009      7.336      0.000       0.050       0.086
# C(AGE_12)[T.25 to 29 years]                         0.2224      0.009     23.495      0.000       0.204       0.241
# C(AGE_12)[T.30 to 34 years]                         0.3265      0.010     34.181      0.000       0.308       0.345
# C(AGE_12)[T.35 to 39 years]                         0.3747      0.010     38.633      0.000       0.356       0.394
# C(AGE_12)[T.40 to 44 years]                         0.4212      0.010     43.202      0.000       0.402       0.440
# C(AGE_12)[T.45 to 49 years]                         0.4334      0.010     43.946      0.000       0.414       0.453
# C(AGE_12)[T.50 to 54 years]                         0.4293      0.010     43.476      0.000       0.410       0.449
# C(AGE_12)[T.55 to 59 years]                         0.4006      0.010     40.445      0.000       0.381       0.420
# C(AGE_12)[T.60 to 64 years]                         0.3368      0.010     32.710      0.000       0.317       0.357
# C(AGE_12)[T.65 to 69 years]                         0.2721      0.012     22.015      0.000       0.248       0.296
# C(AGE_12)[T.70 and over]                            0.1689      0.016     10.887      0.000       0.138       0.199
# C(SEX)[T.Female]                                   -0.1448      0.003    -43.430      0.000      -0.151      -0.138
# C(MARSTAT)[T.Living in common-law]                  0.0099      0.005      1.898      0.058      -0.000       0.020
# C(MARSTAT)[T.Widowed]                              -0.0673      0.016     -4.124      0.000      -0.099      -0.035
# C(MARSTAT)[T.Separated]                            -0.0274      0.011     -2.550      0.011      -0.048      -0.006
# C(MARSTAT)[T.Divorced]                             -0.0344      0.008     -4.071      0.000      -0.051      -0.018
# C(MARSTAT)[T.Single, never married]                -0.0815      0.005    -16.687      0.000      -0.091      -0.072
# C(PROV)[T.Prince Edward Island]                    -0.0853      0.013     -6.724      0.000      -0.110      -0.060
# C(PROV)[T.Nova Scotia]                             -0.1019      0.011     -9.413      0.000      -0.123      -0.081
# C(PROV)[T.New Brunswick]                           -0.0861      0.011     -7.956      0.000      -0.107      -0.065
# C(PROV)[T.Quebec]                                   0.0359      0.009      4.177      0.000       0.019       0.053
# C(PROV)[T.Ontario]                                  0.0651      0.008      7.983      0.000       0.049       0.081
# C(PROV)[T.Manitoba]                                -0.0366      0.010     -3.775      0.000      -0.056      -0.018
# C(PROV)[T.Saskatchewan]                             0.0152      0.010      1.485      0.138      -0.005       0.035
# C(PROV)[T.Alberta]                                  0.1003      0.009     10.609      0.000       0.082       0.119
# C(PROV)[T.British Columbia]                         0.1013      0.009     11.189      0.000       0.084       0.119
# ==============================================================================
# Omnibus:                      695.772   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              954.858
# Skew:                           0.175   Prob(JB):                    4.52e-208
# Kurtosis:                       3.553   Cond. No.                         33.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# !pip install stargazer
# Out:
# Collecting stargazer
#   Downloading stargazer-0.0.6-py3-none-any.whl (11 kB)
# Installing collected packages: stargazer
# Successfully installed stargazer-0.0.6

# %%
from stargazer.stargazer import Stargazer

# Prepare stargazer table
Stargazer([results])
# Out:
# <table style="text-align:center"><tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="1"><em>Dependent variable: lwage</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">C(AGE_12)[T.20 to 24 years]</td><td>0.068<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.009)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.25 to 29 years]</td><td>0.222<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.009)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.30 to 34 years]</td><td>0.326<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.35 to 39 years]</td><td>0.375<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.40 to 44 years]</td><td>0.421<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.45 to 49 years]</td><td>0.433<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.50 to 54 years]</td><td>0.429<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.55 to 59 years]</td><td>0.401<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.60 to 64 years]</td><td>0.337<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.65 to 69 years]</td><td>0.272<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.012)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.70 and over]</td><td>0.169<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Above bachelor's degree]</td><td>0.582<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Bachelor's degree]</td><td>0.460<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.High school graduate]</td><td>0.116<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.015)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Postsecondary certificate or diploma]</td><td>0.271<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.015)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Some high school]</td><td>0.048<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Some postsecondary]</td><td>0.179<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.017)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Divorced]</td><td>-0.034<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.008)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Living in common-law]</td><td>0.010<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.005)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Separated]</td><td>-0.027<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.011)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Single, never married]</td><td>-0.082<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.005)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Widowed]</td><td>-0.067<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Alberta]</td><td>0.100<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.009)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.British Columbia]</td><td>0.101<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.009)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Manitoba]</td><td>-0.037<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.New Brunswick]</td><td>-0.086<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.011)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Nova Scotia]</td><td>-0.102<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.011)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Ontario]</td><td>0.065<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.008)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Prince Edward Island]</td><td>-0.085<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.013)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Quebec]</td><td>0.036<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.009)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Saskatchewan]</td><td>0.015<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(SEX)[T.Female]</td><td>-0.145<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.003)</td></tr>
# <tr><td style="text-align:left">Intercept</td><td>2.838<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.019)</td></tr>
#
# <td colspan="2" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>53443</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.339</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.339</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.381 (df=53410)</td></tr><tr><td style="text-align: left">F Statistic</td><td>855.777<sup>***</sup> (df=32; 53410)</td></tr>
# <tr><td colspan="2" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="1" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
# Obtain the F-statistic, degrees of freedom, and significance level for joint hypothesis
f_statistic = results.fvalue
degrees_of_freedom_model = results.df_model
degrees_of_freedom_residual = results.df_resid
num_regressors = degrees_of_freedom_model + 1  # +1 for the constant term

# Calculate the significance level (p-value) using the F-distribution
p_value = results.f_pvalue

print(f"F-statistic: {f_statistic}")
print(f"Degrees of freedom in the model (n - k - 1): {degrees_of_freedom_model}")
print(f"Number of restrictions (k): {num_regressors}")
print(f"Significance level to reject the null hypothesis: {p_value}")
# Out:
# F-statistic: 855.7772114012181
# Degrees of freedom in the model (n - k - 1): 32.0
# Number of restrictions (k): 33.0
# Significance level to reject the null hypothesis: 0.0

# %%
# Separate models for men and women
model_men = smf.ols('lwage ~ C(EDUC) + C(AGE_12) + C(MARSTAT) + C(PROV)', data=df_notna[df_notna['gender'] == 0])
model_women = smf.ols('lwage ~ C(EDUC) + C(AGE_12) + C(MARSTAT) + C(PROV)', data=df_notna[df_notna['gender'] == 1])

results_men = model_men.fit()
results_women = model_women.fit()

# Get SSR for each separate model
SSR_men = sum(results_men.resid ** 2)
SSR_women = sum(results_women.resid ** 2)

# Combine models for unrestricted model
model_unrestricted = smf.ols('lwage ~ C(EDUC) + C(AGE_12) + C(MARSTAT) + C(PROV) + C(gender)', data=df_notna)
results_unrestricted = model_unrestricted.fit()
SSR_unrestricted = sum(results_unrestricted.resid ** 2)

print(f"SSR for men's model: {SSR_men}")
print(f"SSR for women's model: {SSR_women}")
print(f"SSR for the unrestricted model: {SSR_unrestricted}")
# Out:
# SSR for men's model: 4131.543069816736
# SSR for women's model: 3538.8469428914445
# SSR for the unrestricted model: 7745.796037062718

# %%
Stargazer([results_men, results_women])
# Out:
# <table style="text-align:center"><tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="2"><em>Dependent variable: lwage</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">C(AGE_12)[T.20 to 24 years]</td><td>0.101<sup>***</sup></td><td>0.031<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.013)</td><td>(0.013)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.25 to 29 years]</td><td>0.273<sup>***</sup></td><td>0.167<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.013)</td><td>(0.013)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.30 to 34 years]</td><td>0.377<sup>***</sup></td><td>0.270<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.013)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.35 to 39 years]</td><td>0.422<sup>***</sup></td><td>0.319<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.40 to 44 years]</td><td>0.472<sup>***</sup></td><td>0.364<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.45 to 49 years]</td><td>0.485<sup>***</sup></td><td>0.375<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.50 to 54 years]</td><td>0.476<sup>***</sup></td><td>0.377<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.55 to 59 years]</td><td>0.434<sup>***</sup></td><td>0.361<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.60 to 64 years]</td><td>0.365<sup>***</sup></td><td>0.305<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.015)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.65 to 69 years]</td><td>0.303<sup>***</sup></td><td>0.234<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.018)</td></tr>
# <tr><td style="text-align:left">C(AGE_12)[T.70 and over]</td><td>0.177<sup>***</sup></td><td>0.167<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.021)</td><td>(0.023)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Above bachelor's degree]</td><td>0.501<sup>***</sup></td><td>0.684<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.021)</td><td>(0.025)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Bachelor's degree]</td><td>0.381<sup>***</sup></td><td>0.559<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.024)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.High school graduate]</td><td>0.078<sup>***</sup></td><td>0.177<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.024)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Postsecondary certificate or diploma]</td><td>0.240<sup>***</sup></td><td>0.325<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.024)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Some high school]</td><td>0.026<sup></sup></td><td>0.081<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.021)</td><td>(0.026)</td></tr>
# <tr><td style="text-align:left">C(EDUC)[T.Some postsecondary]</td><td>0.133<sup>***</sup></td><td>0.248<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.022)</td><td>(0.026)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Divorced]</td><td>-0.066<sup>***</sup></td><td>-0.008<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Living in common-law]</td><td>-0.005<sup></sup></td><td>0.023<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.008)</td><td>(0.007)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Separated]</td><td>-0.012<sup></sup></td><td>-0.032<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Single, never married]</td><td>-0.130<sup>***</sup></td><td>-0.031<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.007)</td><td>(0.007)</td></tr>
# <tr><td style="text-align:left">C(MARSTAT)[T.Widowed]</td><td>-0.049<sup></sup></td><td>-0.066<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.031)</td><td>(0.019)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Alberta]</td><td>0.133<sup>***</sup></td><td>0.063<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.013)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.British Columbia]</td><td>0.116<sup>***</sup></td><td>0.087<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.013)</td><td>(0.012)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Manitoba]</td><td>-0.039<sup>***</sup></td><td>-0.035<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.014)</td><td>(0.013)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.New Brunswick]</td><td>-0.115<sup>***</sup></td><td>-0.058<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td><td>(0.015)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Nova Scotia]</td><td>-0.115<sup>***</sup></td><td>-0.086<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.016)</td><td>(0.015)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Ontario]</td><td>0.063<sup>***</sup></td><td>0.070<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.012)</td><td>(0.011)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Prince Edward Island]</td><td>-0.121<sup>***</sup></td><td>-0.047<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.018)</td><td>(0.017)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Quebec]</td><td>0.014<sup></sup></td><td>0.059<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.012)</td><td>(0.012)</td></tr>
# <tr><td style="text-align:left">C(PROV)[T.Saskatchewan]</td><td>0.021<sup></sup></td><td>0.010<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.015)</td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">Intercept</td><td>2.864<sup>***</sup></td><td>2.646<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.025)</td><td>(0.028)</td></tr>
#
# <td colspan="3" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>27136</td><td>26307</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.337</td><td>0.336</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.336</td><td>0.335</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.390 (df=27104)</td><td>0.367 (df=26275)</td></tr><tr><td style="text-align: left">F Statistic</td><td>443.789<sup>***</sup> (df=31; 27104)</td><td>428.886<sup>***</sup> (df=31; 26275)</td></tr>
# <tr><td colspan="3" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="2" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
import statsmodels.formula.api as smf

# Estimated the restricted model on the entire sample excluding 'sex'
model_restricted = smf.ols('lwage ~ C(EDUC) + C(AGE_12) + C(MARSTAT) + C(PROV)', data=df_notna)
results_restricted = model_restricted.fit()

# Get SSR for the restricted model
SSR_restricted = sum(results_restricted.resid ** 2)

# SSR for the unrestricted model obtained in 2.g
SSR_unrestricted = SSR_men + SSR_women  # Obtained from 2.g

# Number of regressors not including 'sex'
num_regressors = len(results_unrestricted.params) - 1  # -1 for intercept

# Degrees of freedom for the unrestricted model from 2.g
degrees_freedom_unrestricted = len(df_notna) - (2 * num_regressors) - 2

# Number of restrictions to be tested
num_restrictions = num_regressors + 1  # +1 for the intercept

# Degrees of freedom for the F-test
degrees_freedom_F = degrees_freedom_unrestricted - (2 * num_restrictions)

# Calculate the F-statistic
F_statistic = ((SSR_restricted - SSR_unrestricted) / num_restrictions) / (SSR_unrestricted / degrees_freedom_F)

print(f"SSR for the restricted model: {SSR_restricted}")
print(f"Number of restrictions (q): {num_restrictions}")
print(f"Degrees of freedom in the unrestricted model: {degrees_freedom_unrestricted}")
print(f"F-statistic: {F_statistic}")
# Out:
# SSR for the restricted model: 8019.334024032804
# Number of restrictions (q): 33
# Degrees of freedom in the unrestricted model: 53377
# F-statistic: 73.49219040107538
